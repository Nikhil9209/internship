# %%
name = ['nikhil', 'ram' ,'sachin','madhu','himanshu','gourav']

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
print([i for i in dir(list) if not i.startswith('__')])
# Out:
# ['append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
len(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 len(list)
#
# TypeError: object of type 'type' has no len()

# %%
len(name)
# Out:
# 6

# %%
name.append('aniket')

# %%
name
# Out:
# ['nikhil', 'ram', 'sachin', 'madhu', 'himanshu', 'gourav', 'aniket']

# %%
name.extend({10,2,3})

# %%
name
# Out:
# ['nikhil', 'ram', 'sachin', 'madhu', 'himanshu', 'gourav', 2, 10, 3]

# %%
name.insert(0,'insert')

# %%
name
# Out:
# ['insert', 'nikhil', 'ram', 'sachin', 'madhu', 'himanshu', 'gourav', 2, 10, 3]

# %%
name.append(['deep'])

# %%
print(name)
# Out:
# ['insert', 'nikhil', 'ram', 'sachin', 'madhu', 'himanshu', 'gourav', 2, 10, 3, ['deep']]

# %%
name.extend(['deep'])

# %%
name
# Out:
# ['insert',
#  'nikhil',
#  'ram',
#  'sachin',
#  'madhu',
#  'himanshu',
#  'gourav',
#  2,
#  10,
#  3,
#  ['deep'],
#  'deep']

# %%
name.append(2,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 name.append(2,2)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
name.extend({2,2})

# %%
name
# Out:
# ['insert',
#  'nikhil',
#  'ram',
#  'sachin',
#  'madhu',
#  'himanshu',
#  'gourav',
#  2,
#  10,
#  3,
#  ['deep'],
#  'deep',
#  2]

# %%
name.remove(2)

# %%
name
# Out:
# ['insert',
#  'nikhil',
#  'ram',
#  'sachin',
#  'madhu',
#  'himanshu',
#  'gourav',
#  10,
#  3,
#  ['deep'],
#  'deep',
#  2]

# %%
name.pop()
# Out:
# 2

# %%
name
# Out:
# ['insert',
#  'nikhil',
#  'ram',
#  'sachin',
#  'madhu',
#  'himanshu',
#  'gourav',
#  10,
#  3,
#  ['deep'],
#  'deep']

# %%
name.clear()

# %%
name
# Out:
# []

# %%
data= [20,30,20,285,26,415,2145,2111,11,1542,11,2]

# %%
data.count(11)
# Out:
# 2

# %%
data.index(30)
# Out:
# 1

# %%
data.index(20,0)
# Out:
# 0

# %%
data.index(20,1)
# Out:
# 2

# %%
data.reverse()

# %%
data
# Out:
# [2, 11, 1542, 11, 2111, 2145, 415, 26, 285, 20, 30, 20]

# %%
data.sort()

# %%
data
# Out:
# [2, 11, 11, 20, 20, 26, 30, 285, 415, 1542, 2111, 2145]

# %%
data.sort(reverse=True)

# %%
data
# Out:
# [2145, 2111, 1542, 415, 285, 30, 26, 20, 20, 11, 11, 2]

# %%
data.copy()
# Out:
# [2145, 2111, 1542, 415, 285, 30, 26, 20, 20, 11, 11, 2]

# %%
data.clear()

# %%
data =[ [23,234],[45.23,4],[803.34,3245]]

# %%
data[0][0]
# Out:
# 23

# %%
data.remove[0][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data.remove[0][0]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
data[0].remove(23)

# %%
data
# Out:
# [[234], [45.23, 4], [803.34, 3245]]

# %%
tup = (90,89.4874,34,49489,38349)

# %%
tup.count(90)
# Out:
# 1

# %%
tup.index(90)
# Out:
# 0

# %%
tup.index(34)
# Out:
# 2

# %% [markdown]
# types of given value

# %%
type(100)
# Out:
# int

# %%
type(105.5)
# Out:
# float

# %%
type(192.56j)
# Out:
# complex

# %%
type(10+6j)
# Out:
# complex

# %%
type('10')
# Out:
# str

# %%
type('hello world')
# Out:
# str

# %%
type([10,20,50,100])
# Out:
# list

# %%
type({'name':'sachin','age':24,'language': 'python'})
# Out:
# dict

# %%
start = int(input("enter a number "))
end = int(input("enter a number "))

while start<=end:
    r =2
    while r<start:
        if r%start==0 :
            print(start)
            break
        r+=1
    start+=1
# Out:
# enter a number  10
# enter a number  20

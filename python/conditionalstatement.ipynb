# %%
age = int(input("enter a number" ))
# Out:
# enter a number 8

# %%
if age>18:
    print("you are eligible")
else:
    print("grow yourself first")
# Out:
# grow yourself first

# %%
money = int(input("enter amount"))
# Out:
# enter amount 200

# %%
if money>=1500:
    print("u can go for shopping")
    if money>200:
        print("you can also go for a date ")
    else:
        print("js go for shopping")
else:
    print("earn money")
# Out:
# earn money

# %%
day = int(input("enter a date"))
# Out:
# enter a date 2

# %%
if day ==1:
    print("mon")
elif day==2:
    print("tue")
elif day==3:
    print("wed")
elif day==4:
    print("thu")
elif day==5:
    print("wed")
elif day==6:
    print("sat")
elif day==7:
    print("son")
else:
    print("invalid")
# Out:
# tue

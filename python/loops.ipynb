# %%
a= 0
b =5
while a<5:
    print("win")
    a =a +1
# Out:
# win
# win
# win
# win
# win

# %%
lst =[10,20,3,10,565,14,50]
i =0
while i <len(lst):
    print(lst[i])
    i= i+1
# Out:
# 10
# 20
# 3
# 10
# 565
# 14
# 50

# %%
data =[10,20,3,10,565,14,50]
i =0
while i <len(data):
    if data[i]%2==0:      
        print(lst[i])
    i= i+1
# Out:
# 10
# 20
# 10
# 14
# 50

# %%
names = ['aman', 'simran', 'deep', 'sachin', 'gaurav', 'ram', 'himanshu']

# %%
i =0
while i<len(names):
    print(names[i])
    i+=1
# Out:
# aman
# simran
# deep
# sachin
# gaurav
# ram
# himanshu

# %%
i =0
while i<len(names):
    if len(names[i])<5:
        print(names[i])
    i+=1
# Out:
# aman
# deep
# ram

# %%
i =0
while i<len(names):
    if names[i].startswith('s'):
        print(names[i].upper())
    i+=1
# Out:
# SIMRAN
# SACHIN

# %%
num = int(input("enter a number"))
# Out:
# enter a number 45

# %%
i =2
while i<num:
    if num%i==0:
        print(f"{num} is not prime")
        break
    i+=1
else:
    print(f"it is  prime number ")
# Out:
# 45 is not prime

# %%
st = int(input("starting"))
end = int(input("ending"))
while st<end:
    i =2
    while i<st:
        if st%i==0:
            print("it is not a prime")
            break
        i+=1
    else:
        print(f"{st} is a prime")
    st+=1
# Out:
# starting 2
# ending 10
# 2 is a prime
# 3 is a prime
# it is not a prime
# 5 is a prime
# it is not a prime
# 7 is a prime
# it is not a prime
# it is not a prime

# %%
import random

# %%
random.randint(1,10)
# Out:
# 10

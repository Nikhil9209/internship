# %%
d ={ "nikhil":1,"jangid":2,"her":3}

# %%
len(d)
# Out:
# 3

# %%
d
# Out:
# {'nikhil': 1, 'jangid': 2, 'her': 3}

# %%
d["nikhil"]
# Out:
# 1

# %%
d['city']=4

# %%
d
# Out:
# {'nikhil': 1, 'jangid': 2, 'her': 3, 'city': 4}

# %%
d.update({"frnd":4})

# %%
d
# Out:
# {'nikhil': 1, 'jangid': 2, 'her': 3, 'city': 4, 'frnd': 4}

# %%
d.update({'frnd':6})

# %%
d
# Out:
# {'nikhil': 1, 'jangid': 2, 'her': 3, 'city': 4, 'frnd': 6}

# %%
d.get('nikhil')
# Out:
# 1

# %%
d.get ('me','not foun')
# Out:
# 'not foun'

# %%
d.keys()
# Out:
# dict_keys(['nikhil', 'jangid', 'her', 'city', 'frnd'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3, 4, 6])

# %%
d.pop('nikhil')
# Out:
# 1

# %%
d
# Out:
# {'jangid': 2, 'her': 3, 'city': 4, 'frnd': 6}

# %%
d.pop('nikhil',"not found")
# Out:
# 'not found'

# %%
d
# Out:
# {'jangid': 2, 'her': 3, 'city': 4, 'frnd': 6}

# %%
d.popitem()
# Out:
# ('frnd', 6)

# %%
d
# Out:
# {'jangid': 2, 'her': 3, 'city': 4}

# %%
d.setdefault('jangid')
# Out:
# 2

# %%
d.setdefault('jangid',5)
# Out:
# 2

# %%
d.setdefault('nikhil',0)
# Out:
# 0

# %%
d
# Out:
# {'jangid': 2, 'her': 3, 'city': 4, 'nikhil': 0}

# %%
data = d.fromkeys(d)

# %%
data
# Out:
# {'jangid': None, 'her': None, 'city': None, 'nikhil': None}

# %%
data.fromkeys([10,20,30,4],'her')
# Out:
# {10: 'her', 20: 'her', 30: 'her', 4: 'her'}

# %%
data = {
    1:{'name':'ram', 'age':25, 'address':'jaipur'},
    2:{'name':'simran', 'age':28, 'address':'jaipur'},
    3:{'name':'sachin', 'age':29, 'address':'jaipur'},
    4:{'name':'rajat', 'age':24, 'address':'jaipur'}
}

# %%
data[1]
# Out:
# {'name': 'ram', 'age': 25, 'address': 'jaipur'}

# %%
data.values()
# Out:
# dict_values([{'name': 'ram', 'age': 25, 'address': 'jaipur'}, {'name': 'simran', 'age': 28, 'address': 'jaipur'}, {'name': 'sachin', 'age': 29, 'address': 'jaipur'}, {'name': 'rajat', 'age': 24, 'address': 'jaipur'}])

# %%
data[1]['age']
# Out:
# 25

# %%
data[1]['name']='her'

# %%
data
# Out:
# {1: {'name': 'her', 'age': 25, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 28, 'address': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur'},
#  4: {'name': 'rajat', 'age': 24, 'address': 'jaipur'}}

# %%
data[1].pop('name')
# Out:
# 'her'

# %%
data
# Out:
# {1: {'age': 25, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 28, 'address': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur'},
#  4: {'name': 'rajat', 'age': 24, 'address': 'jaipur'}}

# %%
s = {12,3423,21,12,32,43,1221}

# %%
s
# Out:
# {12, 21, 32, 43, 1221, 3423}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s.add('nikhil')

# %%
s
# Out:
# {12, 1221, 21, 32, 3423, 43, 'nikhil'}

# %% [raw]
# print(s)

# %%
print(s)
# Out:
# {32, 1221, 21, 'nikhil', 43, 12, 3423}

# %%
s.update("nikhil")

# %%
s
# Out:
# {12, 1221, 21, 32, 3423, 43, 'h', 'i', 'k', 'l', 'n', 'nikhil'}

# %%
s.pop()
# Out:
# 1221

# %%
s.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 s.remove()
#
# TypeError: set.remove() takes exactly one argument (0 given)

# %%
s.pop(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 s.pop(10)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
str = "PThnOHN"

# %%
str.upper()
# Out:
# 'PTHNOHN'

# %%
str
# Out:
# 'PThnOHN'

# %%
str.lower()
# Out:
# 'pthnohn'

# %%
str.swapcase()
# Out:
# 'ptHNohn'

# %%
str= "my name is nikhil "

# %%
str.split()
# Out:
# ['my', 'name', 'is', 'nikhil']

# %%
str.split('e')
# Out:
# ['my nam', ' is nikhil ']

# %%
s = ['my','name','is','nikhil']

# %%
''.join(s)
# Out:
# 'mynameisnikhil'

# %%
'$'.join(s)
# Out:
# 'my$name$is$nikhil'

# %%
str = "nikhil"

# %%
str.isupper()
# Out:
# False

# %%
str.islower()
# Out:
# True

# %%
str = "20a"

# %%
str.isalnum()
# Out:
# True

# %%
str.isalpha()
# Out:
# False

# %%
str.isdigit()
# Out:
# False

# %%
str.isspace()
# Out:
# False

# %%
str= "nikhil"

# %%
str.center(100)
# Out:
# '                                              nikhiil                                               '

# %%
str.center(100,'-')
# Out:
# '-----------------------------------------------nikhil-----------------------------------------------'

# %%
str.ljust(100,'2')
# Out:
# 'nikhil2222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222'

# %%
str.rjust(100,'!')
# Out:
# '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!nikhil'

# %%
str[1:3:1]
# Out:
# 'ik'

# %%
str[::-1]
# Out:
# 'lihkin'

# %%
str[::1]
# Out:
# 'nikhil'

# %%
chance =5

# %%
import random

# %%
randNum= random.randint(1,50)
print(randNum)
# Out:
# 21

# %%
i =0
while i<5:
    user = int(input("enter your guess"))
    if user== randNum :
        print("your guess is correct you are a winner ")
        break
    elif user!=randNum:
        if randNum>user :
            print("think a biigger  number ")
            i+=1
        elif randNum<user:
            print("think a smaller number ")
            i+=1
    if user >50:
        print("you choose a number out of the range ")
else :
    print("you loose")
# Out:
# enter your guess 51
# think a smaller number
# you choose a number out of the range
# enter your guess 21
# your guess is correct you are a winner
